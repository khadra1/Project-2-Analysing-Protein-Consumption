# %%
# Import dependencies

import pandas as pd
from sqlalchemy import create_engine
from pg_keys import pg_key
import numpy as np
import ast
import random

# %% [markdown]
# #  Extract CSVs into DataFrames

# %%
# Import CSV file into DataFrame
csv_file = 'Resources/credits.csv'
credits = pd.read_csv(csv_file)
credits.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
# Import CSV file into DataFrame
csv_file = 'Resources/titles.csv'
titles = pd.read_csv(csv_file)
titles.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm127384      Monty Python and the Holy Grail  MOVIE
# 3   tm70993                        Life of Brian  MOVIE
# 4  tm190788                         The Exorcist  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  King Arthur, accompanied by his squire, recrui...          1975
# 3  Brian Cohen is an average young Jewish man, bu...          1979
# 4  12-year-old Regan MacNeil begins to adapt an e...          1973
#
#   age_certification  runtime                 genres production_countries  \
# 0             TV-MA       48      ['documentation']               ['US']
# 1                 R      113     ['crime', 'drama']               ['US']
# ...

# %% [markdown]
# # Transform credits and titles DataFrames

# %%
# Rename Column id to movie_id
credits = credits.rename(columns={'id': 'movie_id'})
credits.head()
# Out:
#    person_id movie_id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
# Rename Column id to movie_id
titles = titles.rename(columns={'id': 'movie_id'})
titles
# Out:
#        movie_id                                title   type  \
# 0      ts300399  Five Came Back: The Reference Films   SHOW
# 1       tm84618                          Taxi Driver  MOVIE
# 2      tm127384      Monty Python and the Holy Grail  MOVIE
# 3       tm70993                        Life of Brian  MOVIE
# 4      tm190788                         The Exorcist  MOVIE
# ...         ...                                  ...    ...
# 5801  tm1014599                            Fine Wine  MOVIE
# 5802  tm1108171                       Edis Starlight  MOVIE
# 5803  tm1045018                                Clash  MOVIE
# 5804  tm1098060                       Shadow Parties  MOVIE
# 5805   ts271048   Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# 1     A mentally unstable Vietnam War veteran works ...          1976
# ...

# %%
# Merge the two final DataFrames to create a single DataFrame
titles_credits = titles.merge(credits, on = 'movie_id', how = 'left')
titles_credits.head()
# Out:
#    movie_id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2   tm84618                          Taxi Driver  MOVIE
# 3   tm84618                          Taxi Driver  MOVIE
# 4   tm84618                          Taxi Driver  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  A mentally unstable Vietnam War veteran works ...          1976
# 3  A mentally unstable Vietnam War veteran works ...          1976
# 4  A mentally unstable Vietnam War veteran works ...          1976
#
#   age_certification  runtime              genres production_countries  \
# 0             TV-MA       48   ['documentation']               ['US']
# 1                 R      113  ['crime', 'drama']               ['US']
# ...

# %%
# Cleaning merged titles_credits Pandas DataFrame getting rid of certain NaN column values and keeping the relavant ones 
# eg NaN for movies which don't have seasons etc
def repair_array_bound_categories(arr):
    arr = ast.literal_eval(arr)
    
    if len(arr) == 0:
        return np.nan
    
    elif len(arr) == 1:
        return arr[0]
    
    else:
        return random.choice(arr)

# %%
# DataFrame titles_credits columns Production Countries and Genre showing as arrays repaired using NumPy
titles_credits['production_countries'] = titles_credits['production_countries'].apply(repair_array_bound_categories)
titles_credits['genres'] = titles_credits['genres'].apply(repair_array_bound_categories)
titles_credits.head()
# Out:
#    movie_id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2   tm84618                          Taxi Driver  MOVIE
# 3   tm84618                          Taxi Driver  MOVIE
# 4   tm84618                          Taxi Driver  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  A mentally unstable Vietnam War veteran works ...          1976
# 3  A mentally unstable Vietnam War veteran works ...          1976
# 4  A mentally unstable Vietnam War veteran works ...          1976
#
#   age_certification  runtime         genres production_countries  seasons  \
# 0             TV-MA       48  documentation                   US      1.0
# ...

# %% [markdown]
# # Create Database connection

# %%
# Create connection
engine = create_engine(f'postgresql://postgres:{pg_key}@localhost/netflix_db')
connection = engine.connect()

# %% [markdown]
# # Load the 3 DataFrames into Netflix Database

# %%
# Load credits DataFrame onto Netflix Database on PGAdmin as credits table
credits.to_sql('credits', engine, index=True)

# %%
# Make the index the primary key as movie and person id are duplicated
connection.execute('ALTER TABLE credits ADD PRIMARY KEY ("index");')

# %%
# Load titles DataFrame onto Netflix Database on PGAdmin as titles table
titles.to_sql('titles', engine, index=True)

# %%
# Make the index the primary key as movie and person id are duplicated
connection.execute('ALTER TABLE titles ADD PRIMARY KEY ("index");')

# %%
# Load  merged titles_credits DataFrame onto Netflix Database on PGAdmin as titles_credits table
titles_credits.to_sql('titles_credits', engine, index=True)

# %%
# Make the index the primary key as movie and person id are duplicated
connection.execute('ALTER TABLE titles_credits ADD PRIMARY KEY ("index");')

# %%
# Save fiinal merged DataFrame to csv file
titles_credits.to_csv('Resources/titles_credits')
